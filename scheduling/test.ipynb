# %% [markdown]
# ## Task assignment

# %%
from scipy.optimize import linprog
import itertools

# %%
perms = list(itertools.permutations([i for i in range(3)]))
print(perms)
# Out:
# [(0, 1, 2), (0, 2, 1), (1, 0, 2), (1, 2, 0), (2, 0, 1), (2, 1, 0)]
